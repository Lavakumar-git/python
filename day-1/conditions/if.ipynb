# %%
#1
num = 25

if num > 0:
    print("Positive Number")

# %%
#2
age = 20
if age >= 18:
    print("you are elegible for voting")

# %%
#3
num = 100
if num > 100:
    print("greater than 100")

# %%
#4
num = 21

if num % 5 == 0:
    print("Divisible by 5")

# %%
#5
num = 2
if num % 2 == 0:
    print("even number")

# %%
#6
text = "HELLO"
if text.isupper():
    print("upper")
# Out:
# upper

# %%
#7
text = "hii"
if text == "":
    print("empty string")
