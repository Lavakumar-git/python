# %%
#1
num = -25
if num>0:
    print("positive")
else :
    print("negative")
# Out:
# negative

# %%
#2
num = 12
if num % 2 == 0:
    print("even")
else :
    print("odd")
# Out:
# even

# %%
#3
age = 15
if age>=18:
    print("eligible for vote")
else:
    print("not eligible")
# Out:
# not eligible

# %%
#4
marks = 45
if marks >= 35:
    print("pass")
else : 
    print("fail")

# %%
#5
num = 15 
if num % 5 == 0:
    print("divisable")
else:
    print("not divisable")
# Out:
# divisable

# %%
#6
a = 10
b = 15
if a>b:
    print("a is greater")
else:
    print("b is greater")

# %%
#7
a = 10
b = 15
if a>b:
    print("b is smaller")
else:
    print("a is smaller")
# Out:
# a is smaller

# %%
#8
num = 99
if num > 100:
    print("greater then 100")
else:
    print("lessser")
