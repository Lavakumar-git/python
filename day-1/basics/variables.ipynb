# %%
#example 1
name = "Lava"
print(name)

# %%
#example 2
age = 20
print(age)

# %%
#multiple variables
name = "Lava"
age = 20
city = "Chittoor"
print(name)
print(age)
print(city)

# %%
#printing in one line
name = "Lava"
age = 20
print(name, age)

# %%
#variable update
marks = 80
marks = 95
print(marks)

# %%
#copying a variable
a = 10
b = a
print(a)
print(b)

# %%
#single value into multiple variable
a = b = c = 100
print(a)
print(b)
print(c)

# %%
#multiple value in single line
a = b = c = 100
print(a)
print(b)
print(c)

# %%
#valid varible namings
name = "Lava"
student_name = "Rahul"
age2 = 20
_marks = 90
totalMarks = 450

# %%
#invalid varible namings
2age = 20        # Starts with a number
student-name = "Rahul"   # Hyphen (-) is not allowed
my name = "Lava"   # Spaces are not allowed
class = 10         # 'class' is a Python keyword

# %%
#different types of values
name = "Lava"
age = 20
height = 5.8
student = True
print(name)
print(age)
print(height)
print(student)
# Out:
# Lava
# 20
# 5.8
# True
